# %%
import pandas as pd
import numpy as np
import torch
from transformers import BertTokenizer, BertForTokenClassification
from transformers import BertTokenizerFast
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.sequence import pad_sequences


if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
train_df = pd.read_pickle("../data/train.df")
test_df = pd.read_pickle("../data/test.df")
val_df = pd.read_pickle("../data/val.df")

# %%
ignore_genotypes = ['WT', 'wt', 'Wt', 'wild type', 'control', 'KO',
                    'wild-type', 'wildtype', 'Control', 'Wild type', 
                    'Wild-type', 'Wildtype', 'Wild Type', 'knockout']

# %%
# Initialize the BERT tokenizer
tokenizer = BertTokenizerFast.from_pretrained('microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract')

# Define the BIO labels
BIO_LABELS = ['B-GENOTYPE', 'I-GENOTYPE', 'O']


def split_list(lst, size):
    return [lst[i:i+size] for i in range(0, len(lst), size)]

# %%
# Tokenize the text and do BIO labeling
def offset_tokenization(df):
    tokens = []
    offsets = []
    index_offsets = []
    labels = []
    token_label_pairs = []
    for i, row in df.iterrows():
        text = row['Description']
        genotype = row['genotype']
        indexes = row['index_dict']
        train_encodings = tokenizer(text, return_offsets_mapping=True)
        tokenized_text = tokenizer.tokenize(text)
        token_labels = ['O'] * len(tokenized_text)
        # Get the character level offsets
        offsets = train_encodings.offset_mapping[1:-1]
        for key, value in indexes.items():
            if key not in ignore_genotypes:
                for v in value:
                    start = v[0]
                    end = v[1]
                    # Loop through each character level offset in the offsets
                    for k in range(len(offsets)):
                        offset_start = offsets[k][0]
                        offset_end = offsets[k][1]
                        if start <= offset_start and end >= offset_end:
        #                     print(row['tokens'][k], offsets[k], start, offset_start, end, offset_end)
                            if offset_start == start:
                                token_labels[k] = 'B-GENOTYPE'
                            else:
                                token_labels[k] = 'I-GENOTYPE'
        token_chunks = split_list(tokenized_text, 500)
        tokens.extend(token_chunks)
        label_chunks = split_list(token_labels, 500)
        labels.extend(label_chunks)
        token_label_pairs.extend([[(a, b) for a, b in zip(sublist_A, sublist_B)] for sublist_A, sublist_B in zip(token_chunks, label_chunks)])


    # Create a new dataframe with tokenized text and BIO labels
    new_df = pd.DataFrame({'tokens': tokens, 'labels': labels, 'token_label_pairs': token_label_pairs})
    return new_df

# %%
tok_train_df = offset_tokenization(train_df)
tok_test_df = offset_tokenization(test_df)
tok_val_df = offset_tokenization(val_df)

# %%
tok_train_df.iloc[2].token_label_pairs
# Out:
# [('purpose', 'O'),
#  (':', 'O'),
#  ('next', 'O'),
#  ('-', 'O'),
#  ('generation', 'O'),
#  ('sequencing', 'O'),
#  ('(', 'O'),
#  ('ngs', 'O'),
#  (')', 'O'),
#  ('has', 'O'),
#  ('revolution', 'O'),
#  ('##ized', 'O'),
#  ('systems', 'O'),
#  ('-', 'O'),
#  ('based', 'O'),
#  ('analysis', 'O'),
#  ('of', 'O'),
#  ('cellular', 'O'),
#  ('pathways', 'O'),
#  ('.', 'O'),
#  ('the', 'O'),
#  ('goals', 'O'),
#  ('of', 'O'),
#  ('this', 'O'),
#  ('study', 'O'),
#  ('are', 'O'),
#  ('to', 'O'),
#  ('compare', 'O'),
#  ('transcriptome', 'O'),
#  ('##s', 'O'),
#  ('of', 'O'),
#  ('sirt', 'O'),
#  ('##3', 'O'),
#  ('wt', 'O'),
#  ('and', 'O'),
#  ('kr', 'O'),
#  ('macrophages', 'O'),
#  ('with', 'O'),
#  ('high', 'O'),
#  ('-', 'O'),
#  ('throughput', 'O'),
#  ('data', 'O'),
#  ('analysis', 'O'),
#  ('methods', 'O'),
#  (':', 'O'),
#  ('macrophages', 'O'),
#  ("'", 'O'),
#  ('mrna', 'O'),
#  ('profiles', 'O'),
#  ('of', 'O'),
#  ('8', 'O'),
#  ('weeks', 'O'),
#  ('-', 'O'),
#  ('old', 'O'),
#  ('wild', 'O'),
#  ('-', 'O'),
#  ('type', 'O'),
#  ('(', 'O'),
#  ('wt', 'O'),
#  (')', 'O'),
#  ('and', 'O'),
#  ('sirt', 'O'),
#  ('##3', 'O'),
#  ('k2', 'O'),
#  ('##23', 'O'),
#  ('##r', 'O'),
#  ('mice', 'O'),
#  ('were', 'O'),
#  ('generated', 'O'),
#  ('by', 'O'),
#  ('deep', 'O'),
#  ('sequencing', 'O'),
#  (',', 'O'),
#  ('in', 'O'),
#  ('quadrup', 'O'),
#  ('##lic', 'O'),
#  ('##ate', 'O'),
#  (',', 'O'),
#  ('using', 'O'),
#  ('total', 'O'),
#  ('rna', 'O'),
#  ('from', 'O'),
#  ('each', 'O'),
#  ('sample', 'O'),
#  ('was', 'O'),
#  ('quantified', 'O'),
#  ('using', 'O'),
#  ('a', 'O'),
#  ('nanod', 'O'),
#  ('##rop', 'O'),
#  ('nd', 'O'),
#  ('-', 'O'),
#  ('1000', 'O'),
#  ('instrument', 'O'),
#  ('.', 'O'),
#  ('1', 'O'),
#  ('##μg', 'O'),
#  ('total', 'O'),
#  ('rna', 'O'),
#  ('was', 'O'),
#  ('used', 'O'),
#  ('to', 'O'),
#  ('prepare', 'O'),
#  ('the', 'O'),
#  ('sequencing', 'O'),
#  ('library', 'O'),
#  ('in', 'O'),
#  ('the', 'O'),
#  ('following', 'O'),
#  ('steps', 'O'),
#  (':', 'O'),
#  ('1', 'O'),
#  ('.', 'O'),
#  ('total', 'O'),
#  ('rna', 'O'),
#  ('is', 'O'),
#  ('enriched', 'O'),
#  ('by', 'O'),
#  ('oligo', 'O'),
#  ('(', 'O'),
#  ('dt', 'O'),
#  (')', 'O'),
#  ('magnetic', 'O'),
#  ('beads', 'O'),
#  ('(', 'O'),
#  ('rrna', 'O'),
#  ('removed', 'O'),
#  (')', 'O'),
#  (';', 'O'),
#  ('2', 'O'),
#  ('.', 'O'),
#  ('rna', 'O'),
#  ('-', 'O'),
#  ('seq', 'O'),
#  ('library', 'O'),
#  ('preparation', 'O'),
#  ('using', 'O'),
#  ('kap', 'O'),
#  ('##a', 'O'),
#  ('stranded', 'O'),
#  ('rna', 'O'),
#  ('-', 'O'),
#  ('seq', 'O'),
#  ('library', 'O'),
#  ('prep', 'O'),
#  ('kit', 'O'),
#  ('(', 'O'),
#  ('illumina', 'O'),
#  (')', 'O'),
#  (',', 'O'),
#  ('which', 'O'),
#  ('incorporates', 'O'),
#  ('dutp', 'O'),
#  ('into', 'O'),
#  ('the', 'O'),
#  ('second', 'O'),
#  ('cdna', 'O'),
#  ('strand', 'O'),
#  ('and', 'O'),
#  ('renders', 'O'),
#  ('the', 'O'),
#  ('rna', 'O'),
#  ('-', 'O'),
#  ('seq', 'O'),
#  ('library', 'O'),
#  ('strand', 'O'),
#  ('-', 'O'),
#  ('specific', 'O'),
#  ('.', 'O'),
#  ('the', 'O'),
#  ('completed', 'O'),
#  ('libraries', 'O'),
#  ('were', 'O'),
#  ('qualified', 'O'),
#  ('with', 'O'),
#  ('ag', 'O'),
#  ('##ile', 'O'),
#  ('##nt', 'O'),
#  ('210', 'O'),
#  ('##0', 'O'),
#  ('bio', 'O'),
#  ('##analy', 'O'),
#  ('##zer', 'O'),
#  ('and', 'O'),
#  ('quantified', 'O'),
#  ('by', 'O'),
#  ('absolute', 'O'),
#  ('quantification', 'O'),
#  ('qpcr', 'O'),
#  ('method', 'O'),
#  ('.', 'O'),
#  ('to', 'O'),
#  ('sequence', 'O'),
#  ('the', 'O'),
#  ('libraries', 'O'),
#  ('on', 'O'),
#  ('the', 'O'),
#  ('illumina', 'O'),
#  ('his', 'O'),
#  ('##e', 'O'),
#  ('##q', 'O'),
#  ('4000', 'O'),
#  ('instrument', 'O'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('barc', 'O'),
#  ('##oded', 'O'),
#  ('libraries', 'O'),
#  ('were', 'O'),
#  ('mixed', 'O'),
#  (',', 'O'),
#  ('denatured', 'O'),
#  ('to', 'O'),
#  ('single', 'O'),
#  ('stranded', 'O'),
#  ('dna', 'O'),
#  ('in', 'O'),
#  ('naoh', 'O'),
#  (',', 'O'),
#  ('captured', 'O'),
#  ('on', 'O'),
#  ('illumina', 'O'),
#  ('flow', 'O'),
#  ('cell', 'O'),
#  (',', 'O'),
#  ('amplified', 'O'),
#  ('in', 'O'),
#  ('situ', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('subsequently', 'O'),
#  ('sequenced', 'O'),
#  ('for', 'O'),
#  ('150', 'O'),
#  ('cycles', 'O'),
#  ('for', 'O'),
#  ('both', 'O'),
#  ('ends', 'O'),
#  ('on', 'O'),
#  ('illumina', 'O'),
#  ('his', 'O'),
#  ('##e', 'O'),
#  ('##q', 'O'),
#  ('instrument', 'O'),
#  ('.', 'O'),
#  ('results', 'O'),
#  (':', 'O'),
#  ('image', 'O'),
#  ('analysis', 'O'),
#  ('and', 'O'),
#  ('base', 'O'),
#  ('calling', 'O'),
#  ('were', 'O'),
#  ('performed', 'O'),
#  ('using', 'O'),
#  ('sole', 'O'),
#  ('##xa', 'O'),
#  ('pipeline', 'O'),
#  ('v1', 'O'),
#  ('.', 'O'),
#  ('8', 'O'),
#  ('(', 'O'),
#  ('off', 'O'),
#  ('-', 'O'),
#  ('line', 'O'),
#  ('base', 'O'),
#  ('call', 'O'),
#  ('##er', 'O'),
#  ('software', 'O'),
#  (',', 'O'),
#  ('v1', 'O'),
#  ('.', 'O'),
#  ('8', 'O'),
#  (')', 'O'),
#  ('.', 'O'),
#  ('sequence', 'O'),
#  ('quality', 'O'),
#  ('was', 'O'),
#  ('examined', 'O'),
#  ('using', 'O'),
#  ('the', 'O'),
#  ('fast', 'O'),
#  ('##qc', 'O'),
#  ('software', 'O'),
#  ('.', 'O'),
#  ('the', 'O'),
#  ('trim', 'O'),
#  ('##med', 'O'),
#  ('reads', 'O'),
#  ('(', 'O'),
#  ('trim', 'O'),
#  ('##med', 'O'),
#  ('5', 'O'),
#  ('’', 'O'),
#  (',', 'O'),
#  ('3', 'O'),
#  ('’', 'O'),
#  ('-', 'O'),
#  ('adaptor', 'O'),
#  ('bases', 'O'),
#  ('using', 'O'),
#  ('cut', 'O'),
#  ('##adap', 'O'),
#  ('##t', 'O'),
#  (')', 'O'),
#  ('were', 'O'),
#  ('aligned', 'O'),
#  ('to', 'O'),
#  ('reference', 'O'),
#  ('genome', 'O'),
#  ('using', 'O'),
#  ('his', 'O'),
#  ('##at', 'O'),
#  ('##2', 'O'),
#  ('software', 'O'),
#  ('.', 'O'),
#  ('the', 'O'),
#  ('transcript', 'O'),
#  ('abundances', 'O'),
#  ('for', 'O'),
#  ('each', 'O'),
#  ('sample', 'O'),
#  ('was', 'O'),
#  ('estimated', 'O'),
#  ('with', 'O'),
#  ('string', 'O'),
#  ('##ti', 'O'),
#  ('##e', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('fp', 'O'),
#  ('##k', 'O'),
#  ('##m', 'O'),
#  ('value', 'O'),
#  ('for', 'O'),
#  ('gene', 'O'),
#  ('and', 'O'),
#  ('transcript', 'O'),
#  ('level', 'O'),
#  ('were', 'O'),
#  ('calculated', 'O'),
#  ('with', 'O'),
#  ('r', 'O'),
#  ('package', 'O'),
#  ('ball', 'O'),
#  ('##gow', 'O'),
#  ('##n', 'O'),
#  ('.', 'O'),
#  ('the', 'O'),
#  ('differentially', 'O'),
#  ('expressed', 'O'),
#  ('genes', 'O'),
#  ('and', 'O'),
#  ('transcripts', 'O'),
#  ('were', 'O'),
#  ('filtered', 'O'),
#  ('using', 'O'),
#  ('r', 'O'),
#  ('package', 'O'),
#  ('ball', 'O'),
#  ('##gow', 'O'),
#  ('##n', 'O'),
#  ('.', 'O'),
#  ('the', 'O'),
#  ('novel', 'O'),
#  ('genes', 'O'),
#  ('and', 'O'),
#  ('transcripts', 'O'),
#  ('were', 'O'),
#  ('predicted', 'O'),
#  ('from', 'O'),
#  ('assembled', 'O'),
#  ('results', 'O'),
#  ('by', 'O'),
#  ('comparing', 'O'),
#  ('to', 'O'),
#  ('the', 'O'),
#  ('reference', 'O'),
#  ('annotation', 'O'),
#  ('using', 'O'),
#  ('string', 'O'),
#  ('##ti', 'O'),
#  ('##e', 'O'),
#  ('and', 'O'),
#  ('ball', 'O'),
#  ('##gow', 'O'),
#  ('##n', 'O'),
#  (',', 'O'),
#  ('then', 'O'),
#  ('use', 'O'),
#  ('cpa', 'O'),
#  ('##t', 'O'),
#  ('to', 'O'),
#  ('assess', 'O'),
#  ('the', 'O'),
#  ('coding', 'O'),
#  ('potential', 'O'),
#  ('of', 'O'),
#  ('those', 'O'),
#  ('sequences', 'O'),
#  ('.', 'O'),
#  ('then', 'O'),
#  ('use', 'O'),
#  ('rm', 'O'),
#  ('##ats', 'O'),
#  ('to', 'O'),
#  ('detecting', 'O'),
#  ('alternative', 'O'),
#  ('splicing', 'O'),
#  ('events', 'O'),
#  ('and', 'O'),
#  ('plots', 'O'),
#  ('.', 'O'),
#  ('principle', 'O'),
#  ('component', 'O'),
#  ('analysis', 'O'),
#  ('(', 'O'),
#  ('pca', 'O'),
#  (')', 'O'),
#  ('and', 'O'),
#  ('correlation', 'O'),
#  ('analysis', 'O'),
#  ('were', 'O'),
#  ('based', 'O'),
#  ('on', 'O'),
#  ('gene', 'O'),
#  ('expression', 'O'),
#  ('level', 'O'),
#  (',', 'O'),
#  ('hierarchical', 'O'),
#  ('clustering', 'O'),
#  (',', 'O'),
#  ('gene', 'O'),
#  ('ontology', 'O'),
#  (',', 'O'),
#  ('pathway', 'O'),
#  ('analysis', 'O'),
#  (',', 'O'),
#  ('gene', 'O'),
#  ('ontology', 'O'),
#  (',', 'O'),
#  ('pathway', 'O'),
#  ('analysis', 'O'),
#  (',', 'O'),
#  ('scatter', 'O'),
#  ('plots', 'O'),
#  ('and', 'O'),
#  ('vol', 'O'),
#  ('##can', 'O'),
#  ('##o', 'O'),
#  ('plots', 'O'),
#  ('were', 'O'),
#  ('performed', 'O'),
#  ('with', 'O'),
#  ('the', 'O'),
#  ('differentially', 'O'),
#  ('expressed', 'O'),
#  ('genes', 'O'),
#  ('in', 'O'),
#  ('r', 'O'),
#  (',', 'O'),
#  ('py', 'O'),
#  ('##th', 'O'),
#  ('##on', 'O'),
#  ('or', 'O'),
#  ('shell', 'O'),
#  ('environment', 'O'),
#  ('for', 'O'),
#  ('statistical', 'O'),
#  ('computing', 'O'),
#  ('and', 'O'),
#  ('graph', 'O'),
#  ('##ics', 'O'),
#  ('.', 'O'),
#  ('conclusions', 'O'),
#  (':', 'O'),
#  ('our', 'O'),
#  ('study', 'O'),
#  ('represents', 'O'),
#  ('the', 'O'),
#  ('first', 'O'),
#  ('detailed', 'O'),
#  ('analysis', 'O'),
#  ('of', 'O'),
#  ('retinal', 'O'),
#  ('transcriptome', 'O'),
#  ('##s', 'O'),
#  (',', 'O'),
#  ('with', 'O'),
#  ('4', 'O'),
#  ('biologic', 'O'),
#  ('replicates', 'O'),
#  (',', 'O'),
#  ('generated', 'O'),
#  ('by', 'O'),
#  ('rna', 'O'),
#  ('-', 'O'),
#  ('seq', 'O'),
#  ('technology', 'O')]

# %%
train_df.iloc[2].genotype
# Out:
# array(['wild type', 'Sirt3K223R'], dtype=object)

# %%
tok_train_df
# Out:
#                                                  tokens  \
# 0     [we, performed, rnase, ##q, experiments, to, e...
# 1     [lin, ##28, ##b, suppresses, ml, ##l, -, enl, ...
# 2     [purpose, :, next, -, generation, sequencing, ...
# 3     [., the, optimized, data, analysis, workflow, ...
# 4     [stress, granule, and, inflammasome, assembly,...
# ...                                                 ...
# 1116  [the, trem, ##2, -, dap, ##12, receptor, compl...
# 1117  [the, striatum, is, the, main, input, structur...
# 1118  [/, +, mice, and, dl, ##x, ##5, /, 6, -, ci, #...
# 1119  [this, study, was, performed, to, compare, the...
# 1120  [total, gallbladder, /, extrahepatic, duct, ti...
#
#                                                  labels  \
# 0     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 1     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 2     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 4     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# ...                                                 ...
# 1116  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 1117  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 1118  [I-GENOTYPE, I-GENOTYPE, O, O, B-GENOTYPE, I-G...
# 1119  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 1120  [O, O, O, O, O, O, O, O, B-GENOTYPE, I-GENOTYP...
#
#                                       token_label_pairs
# 0     [(we, O), (performed, O), (rnase, O), (##q, O)...
# 1     [(lin, O), (##28, O), (##b, O), (suppresses, O...
# 2     [(purpose, O), (:, O), (next, O), (-, O), (gen...
# 3     [(., O), (the, O), (optimized, O), (data, O), ...
# 4     [(stress, O), (granule, O), (and, O), (inflamm...
# ...                                                 ...
# 1116  [(the, O), (trem, O), (##2, O), (-, O), (dap, ...
# 1117  [(the, O), (striatum, O), (is, O), (the, O), (...
# 1118  [(/, I-GENOTYPE), (+, I-GENOTYPE), (mice, O), ...
# 1119  [(this, O), (study, O), (was, O), (performed, ...
# 1120  [(total, O), (gallbladder, O), (/, O), (extrah...
#
# [1121 rows x 3 columns]

# %%
print("Length of train dataframe:", len(tok_train_df))
print("Length of validation dataframe:", len(tok_test_df))
print("Length of test dataframe:", len(tok_val_df))
# Out:
# Length of train dataframe: 1121
# Length of validation dataframe: 372
# Length of test dataframe: 369

# %%
tok_train_df.to_pickle("../data/pubMed/offset/train.df")
tok_test_df.to_pickle("../data/pubMed/offset/test.df")
tok_val_df.to_pickle("../data/pubMed/offset/val.df")
